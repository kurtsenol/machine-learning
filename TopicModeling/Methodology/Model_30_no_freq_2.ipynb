# %% [markdown]
# <a href="https://colab.research.google.com/github/kurtsenol/machine-learning/blob/master/TopicModeling/Methodology/Model_30_no_freq_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyLDAvis

# %%
# !pip3 install pickle5
# Out:
# Collecting pickle5
#   Downloading https://files.pythonhosted.org/packages/f7/4c/5c4dd0462c8d3a6bc4af500a6af240763c2ebd1efdc736fc2c946d44b70a/pickle5-0.0.11.tar.gz (132kB)
#      |████████████████████████████████| 133kB 5.5MB/s
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py) ... done
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp37-cp37m-linux_x86_64.whl size=219265 sha256=160d96d135803953d40d396749fa77a3fd6dfcfb8bca573c1d796062fc2b93eb
#   Stored in directory: /root/.cache/pip/wheels/a6/90/95/f889ca4aa8b0e0c7f21c8470b6f5d6032f0390a3a141a9a3bd
# Successfully built pickle5
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.11

# %%
import os
import numpy as np
import pandas as pd
import pickle5 as pickle
from pprint import pprint

# %%
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Plotting tools
# import pyLDAvis
# import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt

# %%
id2word = pickle.load(open("/content/drive/MyDrive/Colab Notebooks/TopicModeling/Methodology/id2word_no_freq.pkl", "rb"))
corpus = pickle.load(open("/content/drive/MyDrive/Colab Notebooks/TopicModeling/Methodology/corpus_no_freq.pkl", "rb"))
data_ready = pickle.load(open("/content/drive/MyDrive/Colab Notebooks/TopicModeling/Methodology/data_ready_no_freq.pkl", "rb"))

# %%
# Filter out words that occur less than 20 documents, or more than 60% of the documents.
id2word.filter_extremes(no_below=5, no_above=0.6)

print('Total Vocabulary Size:', len(id2word))
# Out:
# Total Vocabulary Size: 6040

# %%
# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# %% [markdown]
# ### Build the Topic Model

# %%
# !wget http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip

# %%
# !unzip mallet-2.0.8.zip

# %%
mallet_path = '/content/mallet-2.0.8/bin/mallet'

# %%
num_topics=30

# %%
alpha=5/num_topics

# %%
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word, iterations=2000, alpha=alpha)

# %% [markdown]
# Below you can find the 30 topics formed by the model. For each topic there are 10 terms and their relative weights next to it in descending order.

# %%
# Show Topics
pprint(ldamallet.show_topics(formatted=False, num_topics=num_topics))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=data_ready, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# [(0,
#   [('manager', 0.07173506007177406),
#    ('hotel', 0.06362146980808238),
#    ('management', 0.028358558277422376),
#    ('interview', 0.023755656108597284),
#    ('industry', 0.011936339522546418),
#    ('work', 0.010376033702605711),
#    ('conduct', 0.010102980184116086),
#    ('level', 0.008893743173662037),
#    ('company', 0.00869870494616945),
#    ('respondent', 0.008503666718676861)]),
#  (1,
#   [('wine', 0.04368578057673185),
#    ('chinese', 0.041498176997016904),
#    ('family', 0.026052369903878023),
#    ('korean', 0.02466025853496851),
#    ('group', 0.02267152800795492),
#    ('culture', 0.01690420947961551),
#    ('travel', 0.015114352005303281),
#    ('country', 0.013987404706662248),
#    ('child', 0.012330129267484256),
#    ('cultural', 0.012131256214782896)]),
#  (2,
#   [('online', 0.03971179624664879),
#    ('website', 0.038036193029490614),
#    ('host', 0.03155719392314567),
#    ('information', 0.02993744414655943),
#    ('user', 0.024352100089365506),
#    ('airbnb', 0.019772117962466487),
#    ('list', 0.0160857908847185),
#    ('number', 0.01530384271671135),
#    ('post', 0.014242627345844505),
#    ('travel', 0.012120196604110813)]),
#  (3,
#   [('review', 0.10235603301212597),
#    ('rating', 0.04002028678131772),
#    ('word', 0.01904191064594956),
#    ('negative', 0.018673060076536494),
#    ('online', 0.018119784222416894),
#    ('customer', 0.017612614689473928),
#    ('positive', 0.01752040204712066),
#    ('hotel', 0.016413850338881462),
#    ('information', 0.012033749827101295),
#    ('term', 0.01180321822121813)]),
#  (4,
#   [('firm', 0.0918724460867695),
#    ('year', 0.022112733884685317),
#    ('model', 0.021369777308542046),
#    ('asset', 0.019199562046649854),
#    ('performance', 0.015367470232858232),
#    ('size', 0.015015543433632471),
#    ('financial', 0.012845328171740278),
#    ('control', 0.012786673705202652),
#    ('ratio', 0.011594032885604238),
#    ('effect', 0.011574481396758363)]),
#  (5,
#   [('hotel', 0.14608688643507697),
#    ('guest', 0.05400177319255259),
#    ('stay', 0.038647537680341744),
#    ('room', 0.03481905375997421),
#    ('attribute', 0.0333279600225679),
#    ('service', 0.025993390827758523),
#    ('level', 0.016482630772950754),
#    ('quality', 0.01092125413073265),
#    ('green', 0.01084065446925123),
#    ('travel', 0.009470460224067058)]),
#  (6,
#   [('brand', 0.10711254455949754),
#    ('customer', 0.08784586657613308),
#    ('service', 0.042395179086742486),
#    ('quality', 0.03912748260057715),
#    ('satisfaction', 0.022831437786453912),
#    ('experience', 0.021982685452384992),
#    ('loyalty', 0.01837548803259209),
#    ('relationship', 0.012264471227295876),
#    ('consumer', 0.0120098455270752),
#    ('company', 0.009421150908164998)]),
#  (7,
#   [('event', 0.025074513885603444),
#    ('social', 0.02138430240809954),
#    ('network', 0.01878223021242371),
#    ('festival', 0.013246912996167858),
#    ('relationship', 0.012821119364148176),
#    ('community', 0.011165255239627194),
#    ('business', 0.009414770307990728),
#    ('activity', 0.009320149500875242),
#    ('exhibition', 0.008799735061740076),
#    ('local', 0.008373941429720396)]),
#  (8,
#   [('interview', 0.02576879271070615),
#    ('researcher', 0.014280707902575783),
#    ('code', 0.011794725775363588),
#    ('process', 0.011586647976169616),
#    ('question', 0.01057911336954617),
#    ('experience', 0.01052435605396881),
#    ('approach', 0.010283423865428422),
#    ('participant', 0.010108200455580866),
#    ('qualitative', 0.009188277553881198),
#    ('identify', 0.008881636586647977)]),
#  (9,
#   [('article', 0.0400714764351128),
#    ('journal', 0.0229618047799866),
#    ('author', 0.02001340183158365),
#    ('paper', 0.01938798302434666),
#    ('hospitality', 0.018047799865981685),
#    ('tourism', 0.017869108778199687),
#    ('identify', 0.01536743354925173),
#    ('keyword', 0.013580522671431762),
#    ('network', 0.012865758320303775),
#    ('review', 0.012374357828903284)]),
#  (10,
#   [('restaurant', 0.1987833120182503),
#    ('service', 0.025716359614254607),
#    ('dining', 0.023365939649510906),
#    ('food', 0.022190729667139055),
#    ('customer', 0.019010749714838755),
#    ('quality', 0.016660329750095054),
#    ('consumer', 0.011475579827866303),
#    ('experience', 0.011199059832014103),
#    ('respondent', 0.010507759842383602),
#    ('attribute', 0.010438629843420552)]),
#  (11,
#   [('food', 0.0938084354872221),
#    ('menu', 0.04134635362559734),
#    ('restaurant', 0.02217951381674631),
#    ('water', 0.013920631622688551),
#    ('dish', 0.012310409308123832),
#    ('order', 0.011063785580718886),
#    ('healthy', 0.010180760440473717),
#    ('information', 0.009817161853313942),
#    ('number', 0.009038022023685852),
#    ('meal', 0.008882194057760232)]),
#  (12,
#   [('hotel', 0.20833109234658204),
#    ('performance', 0.025305222395525198),
#    ('room', 0.02404130586779971),
#    ('chain', 0.019926854192438014),
#    ('number', 0.01989996235142258),
#    ('property', 0.013257677620609906),
#    ('year', 0.012666057118270317),
#    ('size', 0.012558489754208573),
#    ('market', 0.009707954606572367),
#    ('average', 0.00968106276555693)]),
#  (13,
#   [('tourism', 0.04979985252291162),
#    ('tourist', 0.042030970188559995),
#    ('destination', 0.034709786158221845),
#    ('number', 0.015063731170336037),
#    ('country', 0.01258822290108501),
#    ('local', 0.012324870957547666),
#    ('visitor', 0.012272200568840198),
#    ('travel', 0.01179816707047298),
#    ('region', 0.011403139155166966),
#    ('city', 0.010771094490677341)]),
#  (14,
#   [('price', 0.08151543601921908),
#    ('hotel', 0.045893853205942456),
#    ('room', 0.033854310487656705),
#    ('rate', 0.023084994753410283),
#    ('booking', 0.019826586403048546),
#    ('book', 0.017120450654443033),
#    ('high', 0.01253658805986635),
#    ('table', 0.012481360799690727),
#    ('time', 0.012205224498812613),
#    ('online', 0.011763406417407632)]),
#  (15,
#   [('employee', 0.04018052118212258),
#    ('level', 0.03746299801038482),
#    ('team', 0.032804386858834376),
#    ('manager', 0.03246469646236716),
#    ('performance', 0.026641432522929102),
#    ('group', 0.019216771000145582),
#    ('work', 0.017178628621342264),
#    ('service', 0.016499247828407823),
#    ('individual', 0.014315523851118553),
#    ('organizational', 0.013539088659193479)]),
#  (16,
#   [('service', 0.11293789808917197),
#    ('customer', 0.06628184713375797),
#    ('failure', 0.025238853503184715),
#    ('restaurant', 0.024323248407643314),
#    ('server', 0.018113057324840764),
#    ('emotion', 0.017595541401273885),
#    ('experience', 0.01604299363057325),
#    ('table', 0.014769108280254777),
#    ('recovery', 0.014211783439490446),
#    ('behavior', 0.012460191082802548)]),
#  (17,
#   [('participant', 0.06673335556296543),
#    ('scenario', 0.042258530621318215),
#    ('condition', 0.018672890963654553),
#    ('subject', 0.012048460597977104),
#    ('experiment', 0.01191508280537957),
#    ('design', 0.010825830832499722),
#    ('respondent', 0.010359008558408359),
#    ('manipulation', 0.010336778926308769),
#    ('perceive', 0.010247860397910414),
#    ('question', 0.009247526953428922)]),
#  (18,
#   [('respondent', 0.039957081987846775),
#    ('survey', 0.036418409351174574),
#    ('questionnaire', 0.028422866221667405),
#    ('response', 0.015248274510208503),
#    ('question', 0.014464195442024574),
#    ('participant', 0.014422928122646473),
#    ('measurement', 0.011255661360377183),
#    ('cent', 0.010915205975507845),
#    ('construct', 0.010904889145663321),
#    ('experience', 0.01017239422670202)]),
#  (19,
#   [('work', 0.02599910860199079),
#    ('respondent', 0.024104887832417175),
#    ('hospitality', 0.02343633932550884),
#    ('percent', 0.022544941316297726),
#    ('industry', 0.020390729460704204),
#    ('student', 0.020205021542118555),
#    ('year', 0.017827960184222256),
#    ('career', 0.015673748328628733),
#    ('participant', 0.015599465161194473),
#    ('level', 0.012739563214975486)]),
#  (20,
#   [('questionnaire', 0.03117595922750439),
#    ('survey', 0.02919869773467196),
#    ('respondent', 0.02287487002914756),
#    ('question', 0.016039681592718222),
#    ('group', 0.011710160737723081),
#    ('factor', 0.011488571087664275),
#    ('expert', 0.010431758910460736),
#    ('conduct', 0.009647672456406497),
#    ('section', 0.008897676717745922),
#    ('identify', 0.008676087067687115)]),
#  (21,
#   [('casino', 0.08312122176264715),
#    ('game', 0.02815781100859052),
#    ('table', 0.02060133630289532),
#    ('resort', 0.018533248488705058),
#    ('member', 0.018533248488705058),
#    ('gaming', 0.01741966274260261),
#    ('club', 0.01662424435252943),
#    ('player', 0.01582882596245625),
#    ('reward', 0.014556156538339166),
#    ('play', 0.013044861597200128)]),
#  (22,
#   [('model', 0.030477298182131473),
#    ('input', 0.013569397777203411),
#    ('output', 0.012363229085896443),
#    ('efficiency', 0.012018609459808736),
#    ('function', 0.01008012406306539),
#    ('number', 0.009713965710347204),
#    ('method', 0.009304729904368054),
#    ('score', 0.009261652451107091),
#    ('weight', 0.007969328853278194),
#    ('represent', 0.007473938140777118)]),
#  (23,
#   [('effect', 0.051535836177474405),
#    ('significant', 0.029829351535836178),
#    ('high', 0.01795221843003413),
#    ('difference', 0.01750853242320819),
#    ('support', 0.01658703071672355),
#    ('table', 0.015119453924914676),
#    ('condition', 0.015051194539249147),
#    ('regression', 0.014266211604095563),
#    ('interaction', 0.013447098976109215),
#    ('level', 0.013378839590443685)]),
#  (24,
#   [('company', 0.02455667997400427),
#    ('environmental', 0.018405904744220592),
#    ('innovation', 0.01808095812830749),
#    ('manager', 0.014274440627611178),
#    ('business', 0.01316033794448055),
#    ('employee', 0.012905022746263114),
#    ('practice', 0.012046235261349921),
#    ('performance', 0.009075294773001579),
#    ('industry', 0.008982452882740693),
#    ('management', 0.0087735586296537)]),
#  (25,
#   [('return', 0.042747021723896286),
#    ('risk', 0.04032617697649232),
#    ('market', 0.030387972223991845),
#    ('event', 0.02516404408485698),
#    ('change', 0.019685290182837486),
#    ('stock', 0.01943046441995286),
#    ('rate', 0.018538574249856662),
#    ('period', 0.017901509842645092),
#    ('index', 0.014142829840096833),
#    ('crisis', 0.010384149837548576)]),
#  (26,
#   [('employee', 0.06283508771929824),
#    ('work', 0.0319578947368421),
#    ('questionnaire', 0.03125614035087719),
#    ('hotel', 0.021333333333333333),
#    ('respondent', 0.015789473684210527),
#    ('survey', 0.014975438596491229),
#    ('time', 0.013459649122807017),
#    ('year', 0.011705263157894738),
#    ('supervisor', 0.011242105263157895),
#    ('cent', 0.010498245614035088)]),
#  (27,
#   [('cost', 0.05003264288681821),
#    ('activity', 0.02658911508101371),
#    ('table', 0.02201911092646448),
#    ('exhibit', 0.020654044750430294),
#    ('customer', 0.020594694047124457),
#    ('time', 0.020119888420677787),
#    ('hour', 0.012819751914060182),
#    ('number', 0.012285595584307673),
#    ('level', 0.01222624488100184),
#    ('disability', 0.012107543474390171)]),
#  (28,
#   [('model', 0.04668156008563716),
#    ('time', 0.019919947873033604),
#    ('effect', 0.01726705761891464),
#    ('regression', 0.014846877036209625),
#    ('estimate', 0.014521083496230103),
#    ('period', 0.013729870613422695),
#    ('coefficient', 0.009983244903658196),
#    ('demand', 0.009936702969375407),
#    ('number', 0.009913432002234013),
#    ('price', 0.009797077166527042)]),
#  (29,
#   [('model', 0.04951787374981645),
#    ('construct', 0.04051165750273286),
#    ('factor', 0.039777455091285836),
#    ('measurement', 0.01980714949992658),
#    ('table', 0.017066127163857664),
#    ('variance', 0.014814573102086767),
#    ('reliability', 0.011551451273433294),
#    ('method', 0.01120882348142468),
#    ('dimension', 0.009691471831100813),
#    ('assess', 0.009381475257378735)])]
#
# Coherence Score:  0.49238704451474036

# %%
# pickle.dump(ldamallet, open("/content/drive/MyDrive/Colab Notebooks/TopicModeling/Methodology/model_30_no_freq_2.pkl", "wb"))

# %%
ldamallet = pickle.load(open("/content/drive/MyDrive/Colab Notebooks/TopicModeling/Methodology/model_30_no_freq_2.pkl", "rb"))

# %%
tm_results = ldamallet[corpus]

# %%
# pickle.dump(tm_results, open("/content/drive/MyDrive/Colab Notebooks/TopicModeling/Methodology/tm_results_30_no_freq_2.pkl", "wb"))

# %%
tm_results = pickle.load(open("/content/drive/MyDrive/Colab Notebooks/TopicModeling/Methodology/tm_results_30_no_freq_2.pkl", "rb"))

# %%
corpus_topics = [sorted(topics, key=lambda record: -record[1])[0] for topics in tm_results]

# %%
topics = [[(term, round(wt, 3)) for term, wt in ldamallet.show_topic(n, topn=10)] for n in range(0, ldamallet.num_topics)]

# %% [markdown]
# Below is the Topic-Term matrix shows 10 terms that forms each topic.

# %%
topics_df = pd.DataFrame([[term for term, wt in topic] for topic in topics], columns = ['Term'+str(i) for i in range(1, 11)],
                         index=['Topic '+str(t) for t in range(1, ldamallet.num_topics+1)]).T
topics_df
# Out:
#            Topic 1   Topic 2      Topic 3  ...    Topic 28     Topic 29     Topic 30
# Term1      manager      wine       online  ...        cost        model        model
# Term2        hotel   chinese      website  ...    activity         time    construct
# Term3   management    family         host  ...       table       effect       factor
# Term4    interview    korean  information  ...     exhibit   regression  measurement
# Term5     industry     group         user  ...    customer     estimate        table
# Term6         work   culture       airbnb  ...        time       period     variance
# Term7      conduct    travel         list  ...        hour  coefficient  reliability
# Term8        level   country       number  ...      number       demand       method
# Term9      company     child         post  ...       level       number    dimension
# Term10  respondent  cultural       travel  ...  disability        price       assess
#
# [10 rows x 30 columns]

# %%
pd.set_option('display.max_colwidth', -1)

topics_df = pd.DataFrame([', '.join([term for term, wt in topic]) for topic in topics], columns = ['Terms per Topic'],
                         index=['Topic'+str(t) for t in range(1, ldamallet.num_topics+1)] )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
topics_df
# Out:
#                                                                                                       Terms per Topic
# Topic1   manager, hotel, management, interview, industry, work, conduct, level, company, respondent
# Topic2   wine, chinese, family, korean, group, culture, travel, country, child, cultural
# Topic3   online, website, host, information, user, airbnb, list, number, post, travel
# Topic4   review, rating, word, negative, online, customer, positive, hotel, information, term
# Topic5   firm, year, model, asset, performance, size, financial, control, ratio, effect
# Topic6   hotel, guest, stay, room, attribute, service, level, quality, green, travel
# Topic7   brand, customer, service, quality, satisfaction, experience, loyalty, relationship, consumer, company
# Topic8   event, social, network, festival, relationship, community, business, activity, exhibition, local
# Topic9   interview, researcher, code, process, question, experience, approach, participant, qualitative, identify
# Topic10  article, journal, author, paper, hospitality, tourism, identify, keyword, network, review
# Topic11  restaurant, service, dining, food, customer, quality, consumer, experience, respondent, attribute
# Topic12  food, menu, restaurant, water, dish, order, healthy, information, number, meal
# Topic13  hotel, performance, room, chain, number, property, year, size, market, average
# Topic14  tourism, tourist, destination, number, country, local, visitor, travel, region, city
# Topic15  price, hotel, room, rate, booking, book, high, table, time, online
# Topic16  employee, level, team, manager, performance, group, work, service, individual, organizational
# Topic17  service, customer, failure, restaurant, server, emotion, experience, table, recovery, behavior
# Topic18  participant, scenario, condition, subject, experiment, design, respondent, manipulation, perceive, question
# Topic19  respondent, survey, questionnaire, response, question, participant, measurement, cent, construct, experience
# Topic20  work, respondent, hospitality, percent, industry, student, year, career, participant, level
# Topic21  questionnaire, survey, respondent, question, group, factor, expert, conduct, section, identify
# Topic22  casino, game, table, resort, member, gaming, club, player, reward, play
# Topic23  model, input, output, efficiency, function, number, method, score, weight, represent
# Topic24  effect, significant, high, difference, support, table, condition, regression, interaction, level
# Topic25  company, environmental, innovation, manager, business, employee, practice, performance, industry, management
# Topic26  return, risk, market, event, change, stock, rate, period, index, crisis
# Topic27  employee, work, questionnaire, hotel, respondent, survey, time, year, supervisor, cent
# Topic28  cost, activity, table, exhibit, customer, time, hour, number, level, disability
# Topic29  model, time, effect, regression, estimate, period, coefficient, demand, number, price
# Topic30  model, construct, factor, measurement, table, variance, reliability, method, dimension, assess

# %% [markdown]
# ### WordClouds

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
plt.rcParams['figure.figsize'] = [20, 15]

# %% [markdown]
# Below is the word clouds, one for each topic. The font sizes of words show their relative weights in the topic.

# %%
# Create subplots for each comedian
i=0
for i in range(num_topics):

    wc.generate(text=topics_df["Terms per Topic"][i])
    
    plt.subplot(6, 5, i+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(topics_df.index[i])

plt.show()

# %%
# import pyLDAvis.gensim as gensimvis
# import pyLDAvis

# %%
# from gensim.models.ldamodel import LdaModel
# def convertldaGenToldaMallet(mallet_model):
#     model_gensim = LdaModel(
#         id2word=mallet_model.id2word, num_topics=mallet_model.num_topics,
#         alpha=mallet_model.alpha) # original function has 'eta=0' argument
#     model_gensim.state.sstats[...] = mallet_model.wordtopics
#     model_gensim.sync_state()
#     return model_gensim

# %%
# new_lda = convertldaGenToldaMallet(ldamallet)

# %%
# vis_data = gensimvis.prepare(new_lda, corpus, id2word, sort_topics=False, n_jobs=1)
# pyLDAvis.display(vis_data)
